# %% [markdown]
# ### Medium Q1 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q1 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q2 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q2 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q3 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q3 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q4 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q4 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q5 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q5 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q6 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q6 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q7 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q7 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q8 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q8 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q9 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q9 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q10 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q10 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q11 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q11 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q12 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q12 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q13 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q13 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q14 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q14 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q15 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q15 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q16 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q16 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q17 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q17 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q18 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q18 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q19 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q19 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q20 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q20 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q21 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q21 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q22 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q22 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q23 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q23 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q24 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q24 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q25 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q25 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q26 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q26 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q27 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q27 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q28 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q28 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q29 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q29 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q30 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q30 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q31 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q31 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q32 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q32 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q33 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q33 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q34 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q34 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q35 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q35 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q36 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q36 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q37 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q37 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q38 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q38 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q39 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q39 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q40 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q40 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q41 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q41 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q42 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q42 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q43 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q43 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q44 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q44 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q45 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q45 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q46 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q46 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q47 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q47 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q48 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q48 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q49 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q49 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q50 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q50 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q51 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q51 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q52 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q52 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q53 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q53 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q54 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q54 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q55 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q55 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q56 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q56 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q57 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q57 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q58 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q58 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q59 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q59 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q60 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q60 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q61 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q61 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q62 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q62 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q63 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q63 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q64 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q64 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q65 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q65 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q66 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q66 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q67 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q67 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q68 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q68 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q69 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q69 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q70 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q70 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q71 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q71 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q72 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q72 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q73 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q73 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q74 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q74 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q75 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q75 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q76 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q76 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q77 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q77 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q78 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q78 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q79 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q79 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q80 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q80 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q81 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q81 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q82 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q82 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q83 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q83 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q84 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q84 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q85 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q85 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q86 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q86 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q87 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q87 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q88 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q88 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q89 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q89 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q90 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q90 — Declaration
x = 5
y = 2.5
print(x + y)

# %% [markdown]
# ### Medium Q91 — Print Statement
# Use a single `print()` statement with `\n` to print:
#
# Name: Ali
# Course: Python
# Level: Medium

# %%
# Medium Q91 — Print Statement
print("Name: Ali\nCourse: Python\nLevel: Medium")

# %% [markdown]
# ### Medium Q92 — Input Statement
# Ask the user for their city and country and print them in the format:
# `City - Country`

# %%
# Medium Q92 — Input Statement
city = input("Enter city: ")
country = input("Enter country: ")
print(city + " - " + country)

# %% [markdown]
# ### Medium Q93 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `marks` with values 80, 85, 90 and print each value on a new line.

# %%
# Medium Q93 — Variables (int, string, boolean, float, list, tuple, dict, set)
marks = [80, 85, 90]
for m in marks:
    print(m)

# %% [markdown]
# ### Medium Q94 — Type Casting
# You have the list of strings `["1", "2", "3"]`.
# Convert each value to int and print the new list.

# %%
# Medium Q94 — Type Casting
str_list = ["1", "2", "3"]
int_list = []
for s in str_list:
    int_list.append(int(s))
print(int_list)

# %% [markdown]
# ### Medium Q95 — Declaration
# Declare a dictionary `student` with keys `"name"` and `"age"`.
# Assign any values and print the dictionary.

# %%
# Medium Q95 — Declaration
student = dict(name="Rahul", age=21)
print(student)

# %% [markdown]
# ### Medium Q96 — Print Statement
# Print the sentence:
# `Python programming is fun!`
# using an f-string (formatted string literal).

# %%
# Medium Q96 — Print Statement
message = "Python programming is fun!"
print(f"{message}")

# %% [markdown]
# ### Medium Q97 — Input Statement
# Ask the user for their first name and last name.
# Then print: `Full Name: <first> <last>`.

# %%
# Medium Q97 — Input Statement
first = input("Enter first name: ")
last = input("Enter last name: ")
print("Full Name:", first, last)

# %% [markdown]
# ### Medium Q98 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a tuple `subjects` with `"Maths"`, `"Science"`, `"English"` and print the second subject.

# %%
# Medium Q98 — Variables (int, string, boolean, float, list, tuple, dict, set)
subjects = ("Maths", "Science", "English")
print(subjects[1])

# %% [markdown]
# ### Medium Q99 — Type Casting
# Take an input from the user for a number.
# Convert it to `int` and `float` and print both values.

# %%
# Medium Q99 — Type Casting
value = input("Enter a number: ")
num_int = int(value)
num_float = float(value)
print(num_int, num_float)

# %% [markdown]
# ### Medium Q100 — Declaration
# Declare variables `x = 5` and `y = 2.5`.
# Print their sum.

# %%
# Medium Q100 — Declaration
x = 5
y = 2.5
print(x + y)
