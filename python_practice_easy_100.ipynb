# %% [markdown]
# ### Easy Q1 — Print Statement
# Write a Python program to print the text: `Hello, World!`

# %%
# Easy Q1 — Print Statement
# Simple print statement
print("Hello, World!")

# %% [markdown]
# ### Easy Q2 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q2 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q3 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `numbers` that contains 1, 2 and 3. Print the list.

# %%
# Easy Q3 — Variables (int, string, boolean, float, list, tuple, dict, set)
numbers = [1, 2, 3]
print(numbers)

# %% [markdown]
# ### Easy Q4 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q4 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q5 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q5 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q6 — Print Statement
# Write a Python program to print the numbers 1, 2 and 3 in a single line.

# %%
# Easy Q6 — Print Statement
# Printing multiple values in one line
print(1, 2, 3)

# %% [markdown]
# ### Easy Q7 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q7 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q8 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare a string variable `city` with value `"Bengaluru"` and print it.

# %%
# Easy Q8 — Variables (int, string, boolean, float, list, tuple, dict, set)
city = "Bengaluru"
print(city)

# %% [markdown]
# ### Easy Q9 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q9 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q10 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q10 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q11 — Print Statement
# Write a Python program that prints your favourite programming language on the screen.

# %%
# Easy Q11 — Print Statement
# Replace 'Python' with any language you like
print("Python")

# %% [markdown]
# ### Easy Q12 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q12 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q13 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare an integer variable `age` with value 25 and print it.

# %%
# Easy Q13 — Variables (int, string, boolean, float, list, tuple, dict, set)
age = 25
print(age)

# %% [markdown]
# ### Easy Q14 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q14 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q15 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q15 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q16 — Print Statement
# Write a Python program to print the text: `Hello, World!`

# %%
# Easy Q16 — Print Statement
# Simple print statement
print("Hello, World!")

# %% [markdown]
# ### Easy Q17 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q17 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q18 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `numbers` that contains 1, 2 and 3. Print the list.

# %%
# Easy Q18 — Variables (int, string, boolean, float, list, tuple, dict, set)
numbers = [1, 2, 3]
print(numbers)

# %% [markdown]
# ### Easy Q19 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q19 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q20 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q20 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q21 — Print Statement
# Write a Python program to print the numbers 1, 2 and 3 in a single line.

# %%
# Easy Q21 — Print Statement
# Printing multiple values in one line
print(1, 2, 3)

# %% [markdown]
# ### Easy Q22 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q22 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q23 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare a string variable `city` with value `"Bengaluru"` and print it.

# %%
# Easy Q23 — Variables (int, string, boolean, float, list, tuple, dict, set)
city = "Bengaluru"
print(city)

# %% [markdown]
# ### Easy Q24 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q24 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q25 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q25 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q26 — Print Statement
# Write a Python program that prints your favourite programming language on the screen.

# %%
# Easy Q26 — Print Statement
# Replace 'Python' with any language you like
print("Python")

# %% [markdown]
# ### Easy Q27 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q27 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q28 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare an integer variable `age` with value 25 and print it.

# %%
# Easy Q28 — Variables (int, string, boolean, float, list, tuple, dict, set)
age = 25
print(age)

# %% [markdown]
# ### Easy Q29 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q29 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q30 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q30 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q31 — Print Statement
# Write a Python program to print the text: `Hello, World!`

# %%
# Easy Q31 — Print Statement
# Simple print statement
print("Hello, World!")

# %% [markdown]
# ### Easy Q32 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q32 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q33 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `numbers` that contains 1, 2 and 3. Print the list.

# %%
# Easy Q33 — Variables (int, string, boolean, float, list, tuple, dict, set)
numbers = [1, 2, 3]
print(numbers)

# %% [markdown]
# ### Easy Q34 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q34 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q35 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q35 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q36 — Print Statement
# Write a Python program to print the numbers 1, 2 and 3 in a single line.

# %%
# Easy Q36 — Print Statement
# Printing multiple values in one line
print(1, 2, 3)

# %% [markdown]
# ### Easy Q37 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q37 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q38 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare a string variable `city` with value `"Bengaluru"` and print it.

# %%
# Easy Q38 — Variables (int, string, boolean, float, list, tuple, dict, set)
city = "Bengaluru"
print(city)

# %% [markdown]
# ### Easy Q39 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q39 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q40 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q40 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q41 — Print Statement
# Write a Python program that prints your favourite programming language on the screen.

# %%
# Easy Q41 — Print Statement
# Replace 'Python' with any language you like
print("Python")

# %% [markdown]
# ### Easy Q42 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q42 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q43 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare an integer variable `age` with value 25 and print it.

# %%
# Easy Q43 — Variables (int, string, boolean, float, list, tuple, dict, set)
age = 25
print(age)

# %% [markdown]
# ### Easy Q44 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q44 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q45 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q45 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q46 — Print Statement
# Write a Python program to print the text: `Hello, World!`

# %%
# Easy Q46 — Print Statement
# Simple print statement
print("Hello, World!")

# %% [markdown]
# ### Easy Q47 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q47 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q48 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `numbers` that contains 1, 2 and 3. Print the list.

# %%
# Easy Q48 — Variables (int, string, boolean, float, list, tuple, dict, set)
numbers = [1, 2, 3]
print(numbers)

# %% [markdown]
# ### Easy Q49 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q49 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q50 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q50 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q51 — Print Statement
# Write a Python program to print the numbers 1, 2 and 3 in a single line.

# %%
# Easy Q51 — Print Statement
# Printing multiple values in one line
print(1, 2, 3)

# %% [markdown]
# ### Easy Q52 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q52 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q53 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare a string variable `city` with value `"Bengaluru"` and print it.

# %%
# Easy Q53 — Variables (int, string, boolean, float, list, tuple, dict, set)
city = "Bengaluru"
print(city)

# %% [markdown]
# ### Easy Q54 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q54 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q55 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q55 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q56 — Print Statement
# Write a Python program that prints your favourite programming language on the screen.

# %%
# Easy Q56 — Print Statement
# Replace 'Python' with any language you like
print("Python")

# %% [markdown]
# ### Easy Q57 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q57 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q58 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare an integer variable `age` with value 25 and print it.

# %%
# Easy Q58 — Variables (int, string, boolean, float, list, tuple, dict, set)
age = 25
print(age)

# %% [markdown]
# ### Easy Q59 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q59 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q60 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q60 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q61 — Print Statement
# Write a Python program to print the text: `Hello, World!`

# %%
# Easy Q61 — Print Statement
# Simple print statement
print("Hello, World!")

# %% [markdown]
# ### Easy Q62 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q62 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q63 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `numbers` that contains 1, 2 and 3. Print the list.

# %%
# Easy Q63 — Variables (int, string, boolean, float, list, tuple, dict, set)
numbers = [1, 2, 3]
print(numbers)

# %% [markdown]
# ### Easy Q64 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q64 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q65 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q65 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q66 — Print Statement
# Write a Python program to print the numbers 1, 2 and 3 in a single line.

# %%
# Easy Q66 — Print Statement
# Printing multiple values in one line
print(1, 2, 3)

# %% [markdown]
# ### Easy Q67 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q67 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q68 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare a string variable `city` with value `"Bengaluru"` and print it.

# %%
# Easy Q68 — Variables (int, string, boolean, float, list, tuple, dict, set)
city = "Bengaluru"
print(city)

# %% [markdown]
# ### Easy Q69 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q69 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q70 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q70 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q71 — Print Statement
# Write a Python program that prints your favourite programming language on the screen.

# %%
# Easy Q71 — Print Statement
# Replace 'Python' with any language you like
print("Python")

# %% [markdown]
# ### Easy Q72 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q72 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q73 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare an integer variable `age` with value 25 and print it.

# %%
# Easy Q73 — Variables (int, string, boolean, float, list, tuple, dict, set)
age = 25
print(age)

# %% [markdown]
# ### Easy Q74 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q74 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q75 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q75 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q76 — Print Statement
# Write a Python program to print the text: `Hello, World!`

# %%
# Easy Q76 — Print Statement
# Simple print statement
print("Hello, World!")

# %% [markdown]
# ### Easy Q77 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q77 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q78 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `numbers` that contains 1, 2 and 3. Print the list.

# %%
# Easy Q78 — Variables (int, string, boolean, float, list, tuple, dict, set)
numbers = [1, 2, 3]
print(numbers)

# %% [markdown]
# ### Easy Q79 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q79 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q80 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q80 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q81 — Print Statement
# Write a Python program to print the numbers 1, 2 and 3 in a single line.

# %%
# Easy Q81 — Print Statement
# Printing multiple values in one line
print(1, 2, 3)

# %% [markdown]
# ### Easy Q82 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q82 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q83 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare a string variable `city` with value `"Bengaluru"` and print it.

# %%
# Easy Q83 — Variables (int, string, boolean, float, list, tuple, dict, set)
city = "Bengaluru"
print(city)

# %% [markdown]
# ### Easy Q84 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q84 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q85 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q85 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q86 — Print Statement
# Write a Python program that prints your favourite programming language on the screen.

# %%
# Easy Q86 — Print Statement
# Replace 'Python' with any language you like
print("Python")

# %% [markdown]
# ### Easy Q87 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q87 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q88 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare an integer variable `age` with value 25 and print it.

# %%
# Easy Q88 — Variables (int, string, boolean, float, list, tuple, dict, set)
age = 25
print(age)

# %% [markdown]
# ### Easy Q89 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q89 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q90 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q90 — Declaration
is_active = True
print(is_active)

# %% [markdown]
# ### Easy Q91 — Print Statement
# Write a Python program to print the text: `Hello, World!`

# %%
# Easy Q91 — Print Statement
# Simple print statement
print("Hello, World!")

# %% [markdown]
# ### Easy Q92 — Input Statement
# Write a Python program that asks the user for their age and prints it.

# %%
# Easy Q92 — Input Statement
age = input("Enter your age: ")
print("Your age is", age)

# %% [markdown]
# ### Easy Q93 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Create a list `numbers` that contains 1, 2 and 3. Print the list.

# %%
# Easy Q93 — Variables (int, string, boolean, float, list, tuple, dict, set)
numbers = [1, 2, 3]
print(numbers)

# %% [markdown]
# ### Easy Q94 — Type Casting
# You have a float `3.5`.
# Convert it to an integer and print the result.

# %%
# Easy Q94 — Type Casting
value = 3.5
value_int = int(value)
print(value_int)

# %% [markdown]
# ### Easy Q95 — Declaration
# Declare three variables:
# `a = 5`, `b = 10`, `c = 15` and print them in one line.

# %%
# Easy Q95 — Declaration
a, b, c = 5, 10, 15
print(a, b, c)

# %% [markdown]
# ### Easy Q96 — Print Statement
# Write a Python program to print the numbers 1, 2 and 3 in a single line.

# %%
# Easy Q96 — Print Statement
# Printing multiple values in one line
print(1, 2, 3)

# %% [markdown]
# ### Easy Q97 — Input Statement
# Write a Python program that asks the user for their name and then prints:
# `Hello, <name>!`

# %%
# Easy Q97 — Input Statement
# Taking a single input and using it in output
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %% [markdown]
# ### Easy Q98 — Variables (int, string, boolean, float, list, tuple, dict, set)
# Declare a string variable `city` with value `"Bengaluru"` and print it.

# %%
# Easy Q98 — Variables (int, string, boolean, float, list, tuple, dict, set)
city = "Bengaluru"
print(city)

# %% [markdown]
# ### Easy Q99 — Type Casting
# You have a string `"10"`.
# Convert it to an integer and print the result.

# %%
# Easy Q99 — Type Casting
num_str = "10"
num_int = int(num_str)
print(num_int)

# %% [markdown]
# ### Easy Q100 — Declaration
# Declare a boolean variable `is_active` with value `True` and print it.

# %%
# Easy Q100 — Declaration
is_active = True
print(is_active)
